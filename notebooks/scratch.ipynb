# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
data = {
    1: 421880,
    2: 502093,
    3: 575133,
}
x = list(data.keys())
y = np.array(list(data.values()), dtype=float)

y = (y / y.min()) * 100

plt.figure(figsize=(10, 5))
sns.set_style(style="whitegrid")
sns.barplot(x=x, y=y, palette="Blues_d")
# style y axis as %
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{x:.0f}%"))
# plt.ylim(80, 140)
plt.xticks([])
sns.despine(left=True, bottom=True)

plt.title("Relative pixel intensity of bands", fontsize=20)
# Out:
# /tmp/ipykernel_139656/2524883024.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="Blues_d")
# Text(0.5, 1.0, 'Relative pixel intensity of bands')

# %%
"""
<div>
<c>
    .dataframe tbody tr th:only-of-type {
        vertical-align: middle;
    }

    .dataframe tbody tr th {
        vertical-align: top;
    }

    .dataframe thead th {
        text-align: right;
    }
</style>
<table border="1" class="dataframe">
  <thead>
    <tr style="text-align: right;">
      <th></th>
      <th>Accuracy</th>
      <th>Permutation p-value</th>
      <th>F1 Score</th>
    </tr>
  </thead>
  <tbody>
    <tr>
      <th>Logistic Regression</th>
      <td>68%</td>
      <td>0.0010</td>
      <td>0.61</td>
    </tr>
    <tr>
      <th>Random Forest</th>
      <td>68%</td>
      <td>0.0010</td>
      <td>0.49</td>
    </tr>
    <tr>
      <th>SVC</th>
      <td>45%</td>
      <td>0.0010</td>
      <td>0.34</td>
    </tr>
    <tr>
      <th>Decision Tree</th>
      <td>9%</td>
      <td>0.0380</td>
      <td>0.13</td>
    </tr>
  </tbody>
</table>
</div>
"""
